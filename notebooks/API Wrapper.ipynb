# %%
# ! pip install wbgapi

# %%
import pandas as pd
import matplotlib.pyplot as plt
import wbgapi as wb
# Out:
# /Users/adrianabrazon/Documents/IronHack/final_project/.venv/lib/python3.8/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
wb.source.info()
# Out:
# id    name                                                                  code      concepts  lastupdated
# ----  --------------------------------------------------------------------  ------  ----------  -------------
# 1     Doing Business                                                        DBS              3  2021-08-18
# 2     World Development Indicators                                          WDI              3  2024-03-28
# 3     Worldwide Governance Indicators                                       WGI              3  2023-09-29
# 5     Subnational Malnutrition Database                                     SNM              3  2016-03-21
# 6     International Debt Statistics                                         IDS              4  2024-02-29
# 11    Africa Development Indicators                                         ADI              3  2013-02-22
# 12    Education Statistics                                                  EDS              3  2023-10-12
# ...

# %%
wb.economy.DataFrame()
# Out:
#                             name  aggregate  longitude  latitude region  \
# id
# ABW                        Aruba      False   -70.0167  12.51670    LCN
# AFE  Africa Eastern and Southern       True        NaN       NaN
# AFG                  Afghanistan      False    69.1761  34.52280    SAS
# AFW   Africa Western and Central       True        NaN       NaN
# AGO                       Angola      False    13.2420  -8.81155    SSF
# ..                           ...        ...        ...       ...    ...
# XKX                       Kosovo      False    20.9260  42.56500    ECS
# YEM                  Yemen, Rep.      False    44.2075  15.35200    MEA
# ZAF                 South Africa      False    28.1871 -25.74600    SSF
# ZMB                       Zambia      False    28.2937 -15.39820    SSF
# ZWE                     Zimbabwe      False    31.0672 -17.83120    SSF
#
#     adminregion lendingType incomeLevel capitalCity
# id
# ABW                     LNX         HIC  Oranjestad
# ...

# %%
wb.economy.info()
# Out:
# id    value                                                 region    incomeLevel
# ----  ----------------------------------------------------  --------  -------------
# ABW   Aruba                                                 LCN       HIC
# AFE   Africa Eastern and Southern
# AFG   Afghanistan                                           SAS       LIC
# AFW   Africa Western and Central
# AGO   Angola                                                SSF       LMC
# ALB   Albania                                               ECS       UMC
# AND   Andorra                                               ECS       HIC
# ARB   Arab World
# ARE   United Arab Emirates                                  MEA       HIC
# ARG   Argentina                                             LCN       UMC
# ARM   Armenia                                               ECS       UMC
# ASM   American Samoa                                        EAS       HIC
# ...

# %%
wb.series.info(q="population")
# Out:
# id                       value
# -----------------------  ----------------------------------------------------------------------------------------------------------------------------------------
# EN.ATM.PM25.MC.T1.ZS     PM2.5 pollution, population exposed to levels exceeding WHO Interim Target-1 value (% of total)
# EN.ATM.PM25.MC.T2.ZS     PM2.5 pollution, population exposed to levels exceeding WHO Interim Target-2 value (% of total)
# EN.ATM.PM25.MC.T3.ZS     PM2.5 pollution, population exposed to levels exceeding WHO Interim Target-3 value (% of total)
# EN.ATM.PM25.MC.ZS        PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total)
# EN.POP.DNST              Population density (people per sq. km of land area)
# EN.POP.EL5M.RU.ZS        Rural population living in areas where elevation is below 5 meters (% of total population)
# ...

# %%
wb.series.info(q="inflation")
# Out:
# id                    value
# --------------------  -------------------------------------------------
# FP.CPI.TOTL.ZG        Inflation, consumer prices (annual %)
# NY.GDP.DEFL.KD.ZG     Inflation, GDP deflator (annual %)
# NY.GDP.DEFL.KD.ZG.AD  Inflation, GDP deflator: linked series (annual %)
#                       3 elements

# %%
urban_pop_tot = wb.data.DataFrame('SP.POP.TOTL', wb.region.members('NAC'), time=range(2014,2024))
urban_pop_tot.head()

#'EN.URB.LCTY.UR.ZS','SP.URB.TOTL.IN.ZS','SP.URB.GROW'
# Out:
#               YR2014       YR2015       YR2016       YR2017       YR2018  \
# economy
# BMU          65138.0      65237.0      64554.0      63873.0      63918.0
# CAN       35437435.0   35702908.0   36109487.0   36545236.0   37065084.0
# USA      318386329.0  320738994.0  323071755.0  325122128.0  326838199.0
#
#               YR2019       YR2020       YR2021       YR2022  YR2023
# economy
# BMU          63911.0      63893.0      63764.0      63532.0     NaN
# CAN       37601230.0   38007166.0   38226498.0   38929902.0     NaN
# USA      328329953.0  331511512.0  332031554.0  333287557.0     NaN

# %%
#inflation evolution on consumer prices since the pandemic in the USA :
inflation = wb.data.DataFrame('FP.CPI.TOTL.ZG', ['USA'], time=range(2020,2024))
inflation.head()
# Out:
#            YR2020    YR2021  YR2022  YR2023
# economy
# USA      1.233584  4.697859  8.0028     NaN

# %%
inflation.columns = inflation.columns.str.replace('YR2020', '2020').str.replace('YR2021', '2021').str.replace('YR2022', '2022').str.replace('YR2023', '2023')
inflation

inflation_df = pd.DataFrame(inflation)
inflation_df = inflation_df.reset_index()

inflation_df = inflation_df.set_index('economy').unstack().reset_index()
inflation_df.columns = inflation_df.columns.str.replace('level_0', 'year')
inflation_df.columns = inflation_df.columns.fillna('inflation')
inflation_df
# Out:
#    year economy  inflation
# 0  2020     USA   1.233584
# 1  2021     USA   4.697859
# 2  2022     USA   8.002800
# 3  2023     USA        NaN

# %%
# original csv file ('eviction_rate_data.csv') that was then cleaned in MySQL, before bringing it back here as 'rate_year.csv'
original_csv = pd.read_csv('flat_files/eviction_rate_data.csv', delimiter=';')
print(original_csv.shape)
original_csv.head()
# Out:
# (2176, 7)
#    site_id       month  month_filings  pct_of_historical    avg_filings  \
# 0        0  2020-01-01         103844              0.987  105242.858333
# 1        0  2020-02-01          90424              0.994   91014.025000
# 2        0  2020-03-01          50565              0.606   83380.916667
# 3        0  2020-04-01           6876              0.082   84014.841667
# 4        0  2020-05-01          10781              0.114   94831.725000
#
#    eviction_filing_rate       site
# 0                 0.088  all_sites
# 1                 0.076  all_sites
# 2                 0.043  all_sites
# 3                 0.006  all_sites
# 4                 0.009  all_sites

# %%
eviction_rate_year = pd.read_csv('rate_year.csv')

# %%
eviction_rate_year['economy']='USA'

eviction_rate_year = eviction_rate_year.pivot(index='economy', columns='year', values='eviction_filing_rate')

eviction_rate_year_df = pd.DataFrame(eviction_rate_year)
eviction_rate_year_df = eviction_rate_year_df.reset_index()
eviction_rate_year_df = eviction_rate_year_df.set_index('economy').unstack().reset_index()
eviction_rate_year_df.columns = eviction_rate_year_df.columns.str.replace('0','eviction_rate')
eviction_rate_year_df.columns = eviction_rate_year_df.columns.fillna('eviction_rate')
eviction_rate_year_df
# Out:
#    year economy  eviction_rate
# 0  2020     USA          0.041
# 1  2021     USA          0.048
# 2  2022     USA          0.076
# 3  2023     USA          0.067

# %%
eviction_rate_year = eviction_rate_year.pivot(index='economy', columns='year', values='eviction_filing_rate')

eviction_rate_year_df = pd.DataFrame(eviction_rate_year)
eviction_rate_year_df = eviction_rate_year_df.reset_index()
eviction_rate_year_df = eviction_rate_year_df.set_index('economy').unstack().reset_index()
eviction_rate_year_df.columns = eviction_rate_year_df.columns.str.replace('0','eviction_rate')
eviction_rate_year_df.columns = eviction_rate_year_df.columns.fillna('eviction_rate')
eviction_rate_year_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/IronHack/final_project/.venv/lib/python3.8/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/Documents/IronHack/final_project/.venv/lib/python3.8/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Documents/IronHack/final_project/.venv/lib/python3.8/site-packages/pandas/_libs/index.pyx:155, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'economy'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ...

# %%
eviction_rate_year_df.dtypes
# Out:
# year               int64
# economy           object
# eviction_rate    float64
# dtype: object

# %%
inflation_df.dtypes
# Out:
# year          object
# economy       object
# inflation    float64
# dtype: object

# %%
inflation_df.year = inflation_df.year.astype('int64')

# %%
df = pd.merge(inflation_df, eviction_rate_year_df, on=['year', 'economy'], how='outer', suffixes=('inflation', 'eviction_rate'))
df.inflation=round(df.inflation,2)
df = df.drop(df.index[-1])
df
# Out:
#    year economy  inflation  eviction_rate
# 0  2020     USA       1.23          0.041
# 1  2021     USA       4.70          0.048
# 2  2022     USA       8.00          0.076

# %%
df1 = df.copy()
df1['eviction_rate'] = df1['eviction_rate']*100
df1
# Out:
#    year economy  inflation  eviction_rate
# 0  2020     USA       1.23            4.1
# 1  2021     USA       4.70            4.8
# 2  2022     USA       8.00            7.6

# %%
import os

# %%
# Finally we save our DataFrame as a CSV file!
save_directory1 = '/Users/adrianabrazon/Documents/IronHack/final_project'
csv_file_path = os.path.join(save_directory1, 'eviction_inflation.csv')
df1.to_csv(csv_file_path, index=False)

# %%
plt.figure(figsize=(6, 4))
plt.scatter(df['inflation'], df['eviction_rate'])
plt.xlabel('Inflation')
plt.ylabel('Eviction Rate')
plt.title('Scatter Plot of Inflation vs Eviction Rate')
plt.grid(True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.lineplot(x='year', y='inflation', data=df1, label='Inflation')
sns.lineplot(x='year', y='eviction_rate', data=df1, label='Eviction Rate')
plt.xlabel('')
plt.ylabel('')
plt.title('Trend of Inflation and Eviction Rate per Year')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Merge data
merged_data = pd.merge(mean_temp_kelvin_per_year, mean_percent_bleaching_per_year, on='year')

# Plot comparison trend analysis
fig, ax1 = plt.subplots(figsize=(10, 6))

# %%
df1['eviction_rate']
# Out:
# year
# 2020    0.041
# 2021    0.048
# 2022    0.076
# Name: eviction_rate, dtype: float64

# %%
#'EN.URB.LCTY.UR.ZS','SP.URB.TOTL.IN.ZS','SP.URB.GROW'

# %%
urb_pop_per = wb.data.DataFrame('SP.URB.TOTL.IN.ZS', wb.region.members('NAC'), time=range(2014,2024))
urb_pop_per.head()
# Out:
#           YR2014   YR2015   YR2016   YR2017   YR2018   YR2019   YR2020  \
# economy
# BMU      100.000  100.000  100.000  100.000  100.000  100.000  100.000
# CAN       81.218   81.259   81.300   81.350   81.411   81.482   81.562
# USA       81.483   81.671   81.862   82.058   82.256   82.459   82.664
#
#           YR2021   YR2022  YR2023
# economy
# BMU      100.000  100.000     NaN
# CAN       81.653   81.752     NaN
# USA       82.873   83.084     NaN

# %%
#Population in largest city
pop_lar_cit = wb.data.DataFrame('EN.URB.LCTY', wb.region.members('NAC'), time=range(2014,2024))
urb_pop_per.head()
# Out:
#           YR2014   YR2015   YR2016   YR2017   YR2018   YR2019   YR2020  \
# economy
# BMU      100.000  100.000  100.000  100.000  100.000  100.000  100.000
# CAN       81.218   81.259   81.300   81.350   81.411   81.482   81.562
# USA       81.483   81.671   81.862   82.058   82.256   82.459   82.664
#
#           YR2021   YR2022  YR2023
# economy
# BMU      100.000  100.000     NaN
# CAN       81.653   81.752     NaN
# USA       82.873   83.084     NaN

# %%
pop_den = wb.data.DataFrame('EN.POP.DNST', wb.region.members('NAC'), time=range(2004,2024))
pop_den.head()
# Out:
#               YR2004       YR2005       YR2006       YR2007       YR2008  \
# economy
# BMU      1180.370370  1188.037037  1194.870370  1201.629630  1208.759259
# CAN         3.562583     3.596389     3.632909     3.668361     3.708302
# USA        31.958945    32.254877    32.567400    32.878611    33.243687
#
#               YR2009       YR2010       YR2011       YR2012       YR2013  \
# economy
# BMU      1215.481481  1206.000000  1195.629630  1199.962963  1203.722222
# CAN         3.750885     3.792822     3.830125     3.871939     3.913067
# USA        33.536399    33.815780    34.062444    34.313245    34.551813
#
#               YR2014       YR2015       YR2016       YR2017       YR2018  \
# economy
# BMU      1206.259259  1208.092593  1195.444444  1182.833333  1183.666667
# CAN         3.952605     3.982215     4.027564     4.076166     4.134149
# USA        34.806134    35.063329    35.318347    35.542495    35.730096
#
# ...

# %%
urb_pop_per.T.plot()
# Out:
# <Axes: >

# %%
pop_lar_city = wb.data.DataFrame('EN.URB.LCTY', wb.region.members('NAC'), time=range(2004,2024))
pop_lar_city.head()
# Out:
#              YR2004      YR2005      YR2006      YR2007      YR2008  \
# economy
# BMU             NaN         NaN         NaN         NaN         NaN
# CAN       4947655.0   5035232.0   5124530.0   5215742.0   5308706.0
# USA      18032139.0  18087174.0  18142453.0  18197900.0  18253594.0
#
#              YR2009      YR2010      YR2011      YR2012      YR2013  \
# economy
# BMU             NaN         NaN         NaN         NaN         NaN
# CAN       5403064.0   5499233.0   5592607.0   5660142.0   5728303.0
# USA      18309304.0  18365262.0  18421391.0  18477769.0  18534163.0
#
#              YR2014      YR2015      YR2016      YR2017      YR2018  \
# economy
# BMU             NaN         NaN         NaN         NaN         NaN
# CAN       5797381.0   5867292.0   5938144.0   6009852.0   6082425.0
# USA      18590808.0  18647626.0  18704696.0  18761941.0  18819361.0
#
#              YR2019      YR2020      YR2021      YR2022      YR2023
# economy
# ...

# %%
# Out:
#             YR2014     YR2015     YR2016     YR2017     YR2018     YR2019  \
# economy
# BMU            NaN        NaN        NaN        NaN        NaN        NaN
# CAN      20.142681  20.223794  20.227344  20.215080  20.157129  20.038374
# USA       7.166001   7.118753   7.072441   7.032509   7.000104   6.945737
#
#             YR2020     YR2021     YR2022     YR2023
# economy
# BMU            NaN        NaN        NaN        NaN
# CAN      19.989839  20.038300  19.835918  19.834234
# USA       6.861592   6.840479   6.813270   6.785952

# %%
business = wb.data.DataFrame('IC.REG.DURS', wb.region.members('ECS'), time=range(2003,2024))
business.head()
# Out:
#          YR2003  YR2004  YR2005  YR2006  YR2007  YR2008  YR2009  YR2010  \
# economy
# ALB        41.0    40.0    41.0    39.0    37.0    10.0     6.0     6.0
# AND         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ARM        18.0    18.0    18.0    17.0    17.0    17.0    14.0    14.0
# AUT        25.0    25.0    25.0    25.0    25.0    25.0    25.0    25.0
# AZE       105.0   121.0   113.0    51.0    36.0    10.0    10.0     8.0
#
#          YR2011  YR2012  YR2013  YR2014  YR2015  YR2016  YR2017  YR2018  \
# economy
# ALB         6.0     5.0     5.0     5.0     5.0     5.0     5.0     4.5
# AND         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ARM         8.0     8.0     5.0     5.0     5.0     5.0     5.0     4.0
# AUT        25.0    25.0    25.0    22.0    22.0    21.0    21.0    21.0
# AZE         8.0     8.0     7.0     5.5     3.5     3.5     3.5     3.5
#
#          YR2019  YR2020  YR2021  YR2022
# economy
# ...

# %%
unemployment_rates = wb.data.DataFrame('SL.UEM.TOTL.ZS',['FRA'], time=range(2003,2024))
unemployment_rates
# Out:
#          YR2003  YR2004  YR2005  YR2006  YR2007  YR2008  YR2009  YR2010  \
# economy
# FRA        8.31    8.91    8.88    8.83    8.01    7.39    9.12    9.28
#
#          YR2011  YR2012  YR2013  YR2014  YR2015  YR2016  YR2017  YR2018  \
# economy
# FRA        9.23    9.84    9.91   10.27   10.35   10.06    9.41    9.02
#
#          YR2019  YR2020  YR2021  YR2022
# economy
# FRA        8.41    8.01    7.86    7.31

# %%
unemployment_rates.plot.bar(figsize=(8,4))
# Out:
# <Axes: xlabel='economy'>

# %%
time_to_start_businesss.T.plot()
# Out:
# <Axes: >

# %%
type(business)
# Out:
# pandas.core.frame.DataFrame

# %%
business.shape
# Out:
# (58, 63)

# %%
axis
axes

# %%
business.sort_values(by=['YR2019'],ascending=True)[10:11]
# Out:
#          YR1960  YR1961  YR1962  YR1963  YR1964  YR1965  YR1966  YR1967
# economy
# FRA         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN  \
#
#          YR1968  YR1969  ...  YR2013  YR2014  YR2015  YR2016  YR2017  YR2018
# economy                  ...
# FRA         NaN     NaN  ...     6.5     4.5     4.0     3.5     3.5     3.5  \
#
#          YR2019  YR2020  YR2021  YR2022
# economy
# FRA         4.0     NaN     NaN     NaN
#
# [1 rows x 63 columns]

# %%
g5 = business.sort_values(by=['YR2019'],ascending=True)[10:11]
ax = business.T.plot(color='lightgray', legend=False)
g5.T.plot(ax=ax, figsize=(15,5))
# Out:
# <Axes: >

# %%
time_to_start_businesss
# Out:
#          YR2003  YR2004  YR2005  YR2006  YR2007  YR2008  YR2009  YR2010
# economy
# EST        72.0    72.0    35.0    35.0     6.5     6.5     6.5     6.5  \
# FRA        41.0     7.0     7.0     7.0     7.0     6.5     6.5     6.5
# UKR        41.0    35.0    35.0    34.0    28.0    28.0    28.0    28.0
#
#          YR2011  YR2012  YR2013  YR2014  YR2015  YR2016  YR2017  YR2018
# economy
# EST         6.5     6.5     6.5     4.5     3.5     3.5     3.5     3.5  \
# FRA         6.5     6.5     6.5     4.5     4.0     3.5     3.5     3.5
# UKR        25.0    23.0    22.0    22.0     8.0     6.5     6.5     6.5
#
#          YR2019  YR2020  YR2021  YR2022
# economy
# EST         3.5     NaN     NaN     NaN
# FRA         4.0     NaN     NaN     NaN
# UKR         6.5     NaN     NaN     NaN
